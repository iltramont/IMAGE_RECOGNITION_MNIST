# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#import pickle

from tensorflow.keras.datasets import mnist

from sklearn.ensemble import RandomForestClassifier

from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, make_scorer
from sklearn.metrics import ConfusionMatrixDisplay

from sklearn.decomposition import PCA
# Out:
# WARNING:tensorflow:From C:\Users\lucat\anaconda3\envs\AI_LAB\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Load data
# # Scale data and flat images
#
# As our data represents gray-scale images, we will scale data between 0 and 1.
#
# We will flat images in one dimensional array.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print("x_train shape:", x_train.shape)
print("x_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (60000, 28, 28)
# x_test shape: (10000, 28, 28)
# y_train shape: (60000,)
# y_test shape: (10000,)

# %%
# Reshape
x_train_sc = x_train.reshape(60000, 784)
x_test_sc = x_test.reshape(10000, 784)

# Scale between 0 and 1
x_train_sc = x_train_sc / 255
x_test_sc = x_test_sc / 255

# %% [markdown]
# # Train model

# %%
# Create custom scorer for tuning
def f1_global(y_true, y_pred):
    precision_macro = precision_score(y_true, y_pred, average="macro")
    recall_macro = recall_score(y_true, y_pred, average="macro")
    return (2 * precision_macro * recall_macro) / (precision_macro + recall_macro)

f1_global_scorer = make_scorer(f1_global, greater_is_better=True)

# %%
m = RandomForestClassifier(random_state=25, n_jobs=-1)

parameters = [{
    "criterion": ["gini", "entropy", "log_loss"],
    "max_features": ["sqrt", "log2"]
}]

grid_search = GridSearchCV(m, parameters, verbose=3, scoring=f1_global_scorer)
grid_search.fit(x_train_sc, y_train)
model = grid_search.best_estimator_
score = grid_search.best_score_
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END .criterion=gini, max_features=sqrt;, score=0.968 total time=  12.2s
# [CV 2/5] END .criterion=gini, max_features=sqrt;, score=0.965 total time=   8.6s
# [CV 3/5] END .criterion=gini, max_features=sqrt;, score=0.964 total time=   8.5s
# [CV 4/5] END .criterion=gini, max_features=sqrt;, score=0.963 total time=   8.3s
# [CV 5/5] END .criterion=gini, max_features=sqrt;, score=0.970 total time=   8.4s
# [CV 1/5] END .criterion=gini, max_features=log2;, score=0.964 total time=   3.4s
# [CV 2/5] END .criterion=gini, max_features=log2;, score=0.962 total time=   3.4s
# [CV 3/5] END .criterion=gini, max_features=log2;, score=0.960 total time=   3.4s
# [CV 4/5] END .criterion=gini, max_features=log2;, score=0.960 total time=   3.4s
# [CV 5/5] END .criterion=gini, max_features=log2;, score=0.967 total time=   3.4s
# [CV 1/5] END criterion=entropy, max_features=sqrt;, score=0.967 total time=  10.2s
# [CV 2/5] END criterion=entropy, max_features=sqrt;, score=0.965 total time=  10.3s
# [CV 3/5] END criterion=entropy, max_features=sqrt;, score=0.964 total time=  10.1s
# [CV 4/5] END criterion=entropy, max_features=sqrt;, score=0.965 total time=  10.2s
# [CV 5/5] END criterion=entropy, max_features=sqrt;, score=0.969 total time=  10.4s
# [CV 1/5] END criterion=entropy, max_features=log2;, score=0.964 total time=   4.2s
# [CV 2/5] END criterion=entropy, max_features=log2;, score=0.961 total time=   4.3s
# [CV 3/5] END criterion=entropy, max_features=log2;, score=0.960 total time=   4.3s
# [CV 4/5] END criterion=entropy, max_features=log2;, score=0.961 total time=   4.3s
# [CV 5/5] END criterion=entropy, max_features=log2;, score=0.968 total time=   4.4s
# [CV 1/5] END criterion=log_loss, max_features=sqrt;, score=0.967 total time=  10.3s
# [CV 2/5] END criterion=log_loss, max_features=sqrt;, score=0.965 total time=   8.9s
# [CV 3/5] END criterion=log_loss, max_features=sqrt;, score=0.964 total time=   8.9s
# [CV 4/5] END criterion=log_loss, max_features=sqrt;, score=0.965 total time=   8.7s
# [CV 5/5] END criterion=log_loss, max_features=sqrt;, score=0.969 total time=  11.2s
# [CV 1/5] END criterion=log_loss, max_features=log2;, score=0.964 total time=   7.5s
# [CV 2/5] END criterion=log_loss, max_features=log2;, score=0.961 total time=   7.6s
# [CV 3/5] END criterion=log_loss, max_features=log2;, score=0.960 total time=   7.6s
# [CV 4/5] END criterion=log_loss, max_features=log2;, score=0.961 total time=   7.5s
# [CV 5/5] END criterion=log_loss, max_features=log2;, score=0.968 total time=   7.6s

# %%
print("Mean cross-validated score of the best_estimator:", score)
print("\nModel optimal parameters".upper())
print("criterion:", model.get_params()["criterion"])
print("max_features:", model.get_params()["max_features"])
# Out:
# Mean cross-validated score of the best_estimator: 0.9660093949231952
#
# MODEL OPTIMAL PARAMETERS
# criterion: gini
# max_features: sqrt

# %% [markdown]
# # Test model

# %%
predictions = model.predict(x_test_sc)

accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions, average="macro")
recall = recall_score(y_test, predictions, average="macro")
f1_macro = f1_score(y_test, predictions, average="macro")
f1_glob = (2 * precision * recall) / (precision + recall)

print("Accuracy score: {:.4f}%\nPrecision macro: {:.4f}%\nRecall macro: {:.4f}%".format(accuracy*100,precision*100,recall*100))
print("F1 macro: {:.4f}%\nF1 global: {:.4f}%".format(f1_macro*100, f1_glob*100))
# Out:
# Accuracy score: 96.9500%
# Precision macro: 96.9292%
# Recall macro: 96.9235%
# F1 macro: 96.9243%
# F1 global: 96.9264%

# %%
# Display confusion matrix
cmap = sns.light_palette(color=sns.color_palette("hls", 2)[1], as_cmap=True)
ConfusionMatrixDisplay.from_predictions(y_true=y_test,
                                        y_pred=predictions,
                                        display_labels=model.classes_,
                                        cmap=cmap)
plt.show()

# %% [markdown]
# # PCA
# # Load data

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print("x_train shape:", x_train.shape)
print("x_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (60000, 28, 28)
# x_test shape: (10000, 28, 28)
# y_train shape: (60000,)
# y_test shape: (10000,)

# %% [markdown]
# # Train model with pipeline

# %%
# Reshape
x_train_pca = x_train.reshape(60000, 784)
x_test_pca = x_test.reshape(10000, 784)

# Create pipeline
forest = RandomForestClassifier(random_state=25, n_jobs=-1)
scaler = StandardScaler()
pca = PCA(0.95)

pipe = Pipeline(steps=[("scaler", scaler), ("pca", pca), ("forest", forest)])

parameters = {
    "forest__criterion": ["gini", "entropy", "log_loss"],
    "forest__max_features": ["sqrt", "log2"]
}

grid_search = GridSearchCV(pipe, parameters, verbose=3, scoring=f1_global_scorer)
grid_search.fit(x_train_pca, y_train)

model = grid_search.best_estimator_
score = grid_search.best_score_
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END forest__criterion=gini, forest__max_features=sqrt;, score=0.933 total time= 2.0min
# [CV 2/5] END forest__criterion=gini, forest__max_features=sqrt;, score=0.933 total time=  38.8s
# [CV 3/5] END forest__criterion=gini, forest__max_features=sqrt;, score=0.930 total time=  37.9s
# [CV 4/5] END forest__criterion=gini, forest__max_features=sqrt;, score=0.932 total time=  38.5s
# [CV 5/5] END forest__criterion=gini, forest__max_features=sqrt;, score=0.938 total time= 2.6min
# [CV 1/5] END forest__criterion=gini, forest__max_features=log2;, score=0.919 total time=  21.0s
# [CV 2/5] END forest__criterion=gini, forest__max_features=log2;, score=0.918 total time=  20.9s
# [CV 3/5] END forest__criterion=gini, forest__max_features=log2;, score=0.916 total time=  21.3s
# [CV 4/5] END forest__criterion=gini, forest__max_features=log2;, score=0.916 total time=  21.2s
# [CV 5/5] END forest__criterion=gini, forest__max_features=log2;, score=0.928 total time=  21.0s
# [CV 1/5] END forest__criterion=entropy, forest__max_features=sqrt;, score=0.933 total time= 3.2min
# [CV 2/5] END forest__criterion=entropy, forest__max_features=sqrt;, score=0.932 total time= 1.3min
# [CV 3/5] END forest__criterion=entropy, forest__max_features=sqrt;, score=0.931 total time= 1.1min
# [CV 4/5] END forest__criterion=entropy, forest__max_features=sqrt;, score=0.930 total time= 1.1min
# [CV 5/5] END forest__criterion=entropy, forest__max_features=sqrt;, score=0.939 total time= 1.1min
# [CV 1/5] END forest__criterion=entropy, forest__max_features=log2;, score=0.922 total time=  34.9s
# [CV 2/5] END forest__criterion=entropy, forest__max_features=log2;, score=0.920 total time=  34.2s
# [CV 3/5] END forest__criterion=entropy, forest__max_features=log2;, score=0.917 total time=  34.7s
# [CV 4/5] END forest__criterion=entropy, forest__max_features=log2;, score=0.917 total time=  34.5s
# [CV 5/5] END forest__criterion=entropy, forest__max_features=log2;, score=0.926 total time=  34.7s
# [CV 1/5] END forest__criterion=log_loss, forest__max_features=sqrt;, score=0.933 total time= 1.1min
# [CV 2/5] END forest__criterion=log_loss, forest__max_features=sqrt;, score=0.932 total time= 1.1min
# [CV 3/5] END forest__criterion=log_loss, forest__max_features=sqrt;, score=0.931 total time= 1.1min
# [CV 4/5] END forest__criterion=log_loss, forest__max_features=sqrt;, score=0.930 total time= 1.1min
# [CV 5/5] END forest__criterion=log_loss, forest__max_features=sqrt;, score=0.939 total time= 1.1min
# [CV 1/5] END forest__criterion=log_loss, forest__max_features=log2;, score=0.922 total time=  34.6s
# [CV 2/5] END forest__criterion=log_loss, forest__max_features=log2;, score=0.920 total time=  34.1s
# [CV 3/5] END forest__criterion=log_loss, forest__max_features=log2;, score=0.917 total time=  34.2s
# [CV 4/5] END forest__criterion=log_loss, forest__max_features=log2;, score=0.917 total time=  34.3s
# [CV 5/5] END forest__criterion=log_loss, forest__max_features=log2;, score=0.926 total time=  34.3s

# %%
print("Mean cross-validated score of the best_estimator:", score)
print("\nModel optimal parameters".upper())
print("criterion:", model.get_params()["forest__criterion"])
print("max_features:", model.get_params()["forest__max_features"])
# Out:
# Mean cross-validated score of the best_estimator: 0.9332254088628833
#
# MODEL OPTIMAL PARAMETERS
# criterion: entropy
# max_features: sqrt

# %% [markdown]
# # Test model

# %%
predictions = model.predict(x_test_pca)

accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions, average="macro")
recall = recall_score(y_test, predictions, average="macro")
f1_macro = f1_score(y_test, predictions, average="macro")
f1_glob = (2 * precision * recall) / (precision + recall)

print("Accuracy score: {:.4f}%\nPrecision macro: {:.4f}%\nRecall macro: {:.4f}%".format(accuracy*100,precision*100,recall*100))
print("F1 macro: {:.4f}%\nF1 global: {:.4f}%".format(f1_macro*100, f1_glob*100))
# Out:
# Accuracy score: 93.7200%
# Precision macro: 93.7007%
# Recall macro: 93.6385%
# F1 macro: 93.6495%
# F1 global: 93.6696%

# %%
# Display confusion matrix
ConfusionMatrixDisplay.from_predictions(y_true=y_test,
                                        y_pred=predictions,
                                        display_labels=model.classes_,
                                        cmap=cmap)
plt.show()
